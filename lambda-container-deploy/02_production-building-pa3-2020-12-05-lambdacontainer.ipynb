# %%
import sys
# !{sys.executable} -m pip install fastai --upgrade #==2.0
# Out:
# Requirement already up-to-date: fastai in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (2.1.8)
# Requirement already satisfied, skipping upgrade: fastcore>=1.3.8 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from fastai) (1.3.10)
# Requirement already satisfied, skipping upgrade: scikit-learn in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from fastai) (0.23.2)
# Requirement already satisfied, skipping upgrade: scipy in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from fastai) (1.5.2)
# Requirement already satisfied, skipping upgrade: spacy in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from fastai) (2.3.2)
# Requirement already satisfied, skipping upgrade: torch>=1.7.0 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from fastai) (1.7.0)
# Requirement already satisfied, skipping upgrade: matplotlib in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from fastai) (3.3.2)
# Requirement already satisfied, skipping upgrade: packaging in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from fastai) (20.4)
# Requirement already satisfied, skipping upgrade: pandas in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from fastai) (1.1.2)
# Requirement already satisfied, skipping upgrade: fastprogress>=0.2.4 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from fastai) (1.0.0)
# Requirement already satisfied, skipping upgrade: requests in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from fastai) (2.24.0)
# Requirement already satisfied, skipping upgrade: pillow in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from fastai) (7.2.0)
# Requirement already satisfied, skipping upgrade: pyyaml in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from fastai) (5.3.1)
# Requirement already satisfied, skipping upgrade: pip in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from fastai) (20.2.2)
# Requirement already satisfied, skipping upgrade: torchvision>=0.8 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from fastai) (0.8.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from scikit-learn->fastai) (0.16.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from scikit-learn->fastai) (2.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from scikit-learn->fastai) (1.19.2)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from spacy->fastai) (2.0.3)
# Requirement already satisfied, skipping upgrade: blis<0.5.0,>=0.4.0 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from spacy->fastai) (0.4.1)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from spacy->fastai) (1.0.2)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.38.0 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from spacy->fastai) (4.49.0)
# Requirement already satisfied, skipping upgrade: catalogue<1.1.0,>=0.0.7 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from spacy->fastai) (1.0.0)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.4.0 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from spacy->fastai) (0.8.0)
# Requirement already satisfied, skipping upgrade: thinc==7.4.1 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from spacy->fastai) (7.4.1)
# Requirement already satisfied, skipping upgrade: plac<1.2.0,>=0.9.6 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from spacy->fastai) (1.1.3)
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from spacy->fastai) (3.0.2)
# Requirement already satisfied, skipping upgrade: setuptools in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from spacy->fastai) (49.6.0.post20200814)
# Requirement already satisfied, skipping upgrade: srsly<1.1.0,>=1.0.2 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from spacy->fastai) (1.0.2)
# Requirement already satisfied, skipping upgrade: typing-extensions in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from torch>=1.7.0->fastai) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: dataclasses in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from torch>=1.7.0->fastai) (0.7)
# Requirement already satisfied, skipping upgrade: future in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from torch>=1.7.0->fastai) (0.18.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from matplotlib->fastai) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from matplotlib->fastai) (2.4.7)
# Requirement already satisfied, skipping upgrade: certifi>=2020.06.20 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from matplotlib->fastai) (2020.6.20)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from matplotlib->fastai) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from matplotlib->fastai) (1.2.0)
# Requirement already satisfied, skipping upgrade: six in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from packaging->fastai) (1.15.0)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from pandas->fastai) (2020.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from requests->fastai) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from requests->fastai) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from requests->fastai) (1.25.10)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.20; python_version < "3.8" in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from catalogue<1.1.0,>=0.0.7->spacy->fastai) (1.7.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /home/ec2-user/SageMaker/.env/fastai/lib/python3.6/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy->fastai) (3.1.0)

# %%
import fastai
print(fastai.__version__ ) # should be 2.0.0
# Out:
# 2.1.8

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# # From Model to Production

# %% [markdown]
# ## The Practice of Deep Learning

# %% [markdown]
# ### Starting Your Project

# %% [markdown]
# ### The State of Deep Learning

# %% [markdown]
# #### Computer vision

# %% [markdown]
# #### Text (natural language processing)

# %% [markdown]
# #### Combining text and images

# %% [markdown]
# #### Tabular data

# %% [markdown]
# #### Recommendation systems

# %% [markdown]
# #### Other data types

# %% [markdown]
# ### The Drivetrain Approach

# %% [markdown]
# ## Gathering Data

# %% [markdown]
# # clean
# To download images with Bing Image Search, sign up at Microsoft for a free account. You will be given a key, which you can copy and enter in a cell as follows (replacing 'XXX' with your key and executing it):

# %% [markdown]
# ## Google Images

# %%
from fastai.vision.utils import *
from pathlib import Path

# %%
classes = ['construction', 'built']
base_dir = Path('.')
for c in classes:
    dest = base_dir/'images'/c
    dest.mkdir(parents=True, exist_ok=True)
    url_file = base_dir/f'{c}.csv'
#    download_images(dest, url_file)

# %%
base_dir = Path('.')
base_dir
# Out:
# Path('.')

# %%
bear_types = 'construction','built',
#path = Path(base_dir)
#path

# %%
for c in classes:
    for f in list((base_dir/'images'/'emlk'/c).glob('*.jpg'))[:3]:
        print(f)
# Out:
# images/emlk/construction/00000003.jpg
# images/emlk/construction/00000009.jpg
# images/emlk/construction/00000010.jpg
# images/emlk/built/00000003.jpg
# images/emlk/built/00000009.jpg
# images/emlk/built/00000010.jpg

# %%
fns = get_image_files('images/emlk')
fns
# Out:
# (#60) [Path('images/emlk/built/00000003.jpg'),Path('images/emlk/built/00000009.jpg'),Path('images/emlk/built/00000010.jpg'),Path('images/emlk/built/00000000.jpg'),Path('images/emlk/built/00000012.jpg'),Path('images/emlk/built/00000026.jpg'),Path('images/emlk/built/00000027.jpg'),Path('images/emlk/built/00000004.jpg'),Path('images/emlk/built/00000011.jpg'),Path('images/emlk/built/00000021.jpg')...]

# %%
path = Path('images/emlk')
path
# Out:
# Path('images/emlk')

# %% [markdown]
# ### Sidebar: Getting Help in Jupyter Notebooks

# %% [markdown]
# ### End sidebar

# %% [markdown]
# ## From Data to DataLoaders

# %%
bears = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
my_batch_size=12

# %%
dls = bears.dataloaders(path,bs=my_batch_size)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = bears.dataloaders(path,bs=my_batch_size)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = bears.dataloaders(path,bs=my_batch_size)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = bears.dataloaders(path,bs=my_batch_size)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %% [markdown]
# ### Data Augmentation

# %%
bears = bears.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = bears.dataloaders(path,bs=my_batch_size)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %% [markdown]
# ## Training Your Model, and Using It to Clean Your Data

# %%
bears = bears.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = bears.dataloaders(path,bs=my_batch_size)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /home/ec2-user/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# HBox(children=(FloatProgress(value=0.0, max=46827520.0), HTML(value='')))
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.964599</td>
#       <td>2.148597</td>
#       <td>0.666667</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.916944</td>
#       <td>0.862174</td>
#       <td>0.500000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.812311</td>
#       <td>0.305377</td>
#       <td>0.166667</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.741642</td>
#       <td>0.155830</td>
#       <td>0.000000</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.633119</td>
#       <td>0.141991</td>
#       <td>0.000000</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(4, nrows=2)

# %% [markdown]
# ## Turning Your Model into an Online Application

# %% [markdown]
# ### Using the Model for Inference

# %%
learn.path
# Out:
# Path('.')

# %%
learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('images/grizzly.jpg')

# %%
learn_inf.dls.vocab

# %% [markdown]
# ### Creating a Notebook App from the Model

# %%
btn_upload = widgets.FileUpload()
btn_upload

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/grizzly.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl

# %%
pred,pred_idx,probs = learn_inf.predict(img)

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred

# %%
btn_run = widgets.Button(description='Classify')
btn_run

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])

# %% [markdown]
# ### Turning Your Notebook into a Real App

# %%
#hide
# !pip install voila
# !jupyter serverextension enable voila —sys-prefix

# %% [markdown]
# ### Deploying your app

# %% [markdown]
# ## How to Avoid Disaster

# %% [markdown]
# ### Unforeseen Consequences and Feedback Loops

# %% [markdown]
# ## Get Writing!

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# 1. Provide an example of where the bear classification model might work poorly in production, due to structural or style differences in the training data.
# 1. Where do text models currently have a major deficiency?
# 1. What are possible negative societal implications of text generation models?
# 1. In situations where a model might make mistakes, and those mistakes could be harmful, what is a good alternative to automating a process?
# 1. What kind of tabular data is deep learning particularly good at?
# 1. What's a key downside of directly using a deep learning model for recommendation systems?
# 1. What are the steps of the Drivetrain Approach?
# 1. How do the steps of the Drivetrain Approach map to a recommendation system?
# 1. Create an image recognition model using data you curate, and deploy it on the web.
# 1. What is `DataLoaders`?
# 1. What four things do we need to tell fastai to create `DataLoaders`?
# 1. What does the `splitter` parameter to `DataBlock` do?
# 1. How do we ensure a random split always gives the same validation set?
# 1. What letters are often used to signify the independent and dependent variables?
# 1. What's the difference between the crop, pad, and squish resize approaches? When might you choose one over the others?
# 1. What is data augmentation? Why is it needed?
# 1. What is the difference between `item_tfms` and `batch_tfms`?
# 1. What is a confusion matrix?
# 1. What does `export` save?
# 1. What is it called when we use a model for getting predictions, instead of training?
# 1. What are IPython widgets?
# 1. When might you want to use CPU for deployment? When might GPU be better?
# 1. What are the downsides of deploying your app to a server, instead of to a client (or edge) device such as a phone or PC?
# 1. What are three examples of problems that could occur when rolling out a bear warning system in practice?
# 1. What is "out-of-domain data"?
# 1. What is "domain shift"?
# 1. What are the three steps in the deployment process?

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. Consider how the Drivetrain Approach maps to a project or problem you're interested in.
# 1. When might it be best to avoid certain types of data augmentation?
# 1. For a project you're interested in applying deep learning to, consider the thought experiment "What would happen if it went really, really well?"
# 1. Start a blog, and write your first blog post. For instance, write about what you think deep learning might be useful for in a domain you're interested in.
